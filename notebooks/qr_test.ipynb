# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/Users/davinan/Dropbox/hextronics/Hextronics")

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

imgs_path = "../imgs/shapes"

# %%
ref_path = None
arrow_ref_path = os.path.join(imgs_path, "Arrow", "Arrow1.jpg") 

arrow_imgs = [os.path.join(imgs_path, "Arrow", f"Arrow{i}.jpg") for i in range(2, 6)]

# %%
from cv.feature_extraction import find_homography, apply_homography, get_platform_mask, decompose_homography
from matplotlib.pyplot import figure
from PIL import Image
from pyzbar import pyzbar
zoom_imgs = [os.path.join("../imgs", "zoom", f"zoom{i}.jpg") for i in range(1, 11)]
def test(img_paths, thres=None):
    for path in img_paths:
        ref_img = plt.imread(path)
        print(pyzbar.decode(ref_img))

# %%
test(zoom_imgs)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
img = plt.imread(zoom_imgs[0])

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F9F700B03A0>
