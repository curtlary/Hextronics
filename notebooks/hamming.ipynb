# %%
from ar_markers import detect_markers

# %%
import matplotlib.pyplot as plt
import numpy as np
detect_markers((plt.imread("/Users/davinan/Desktop/ham.png")*255).astype(np.uint8))
# Out:
# []

# %%
img = plt.imread("/Users/davinan/Desktop/markers.jpg")
# img = (plt.imread("/Users/davinan/Desktop/ham.png")*255).astype(np.uint8)
detect_markers(img)
# Out:
# [<Marker id=2365 center=(45, 168)>, <Marker id=2621 center=(45, 168)>]

# %%
plt.imshow(img)
plt.scatter([45], [168])
plt.show()
#https://www.pyimagesearch.com/2021/01/04/opencv-augmented-reality-ar/

# %%
import cv2
arucoDict = cv2.aruco.Dictionary_get(cv2.aruco.DICT_ARUCO_ORIGINAL)
arucoParams = cv2.aruco.DetectorParameters_create()
(corners, ids, rejected) = cv2.aruco.detectMarkers(img, arucoDict, parameters=arucoParams)

# %%
plt.scatter(*corners[0][0].T)
plt.imshow(img)
plt.show()

# %%
ids
# Out:
# array([[33]], dtype=int32)
